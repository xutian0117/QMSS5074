# %% [markdown]
# # Tian Xu
# # World Happiness Classification Competition
#
# ##### This report shows the exploration and application of 4 classification models to predict World Happiness. It encompasses EDA, feature examination, and model selection. The final model of the project is submitted to final model to the World Happiness AI Model Share competition.
#
#
# ##### Decision Tree Classifier: This model displayed the best performance in terms of Precision (68.07%) and Recall (53.76%). The best hyper parameter parameters identified for this model are:
# ##### Criterion: 'gini'
# ##### Max Depth: None
# ##### Min Samples Leaf: 4
# ##### Min Samples Split: 2

# %% [markdown]
# ## Get data in and set up X_train, X_test, y_train objects

# %%
#Get competition data from course folder and unzip
# importing the zipfile module
from zipfile import ZipFile

# loading the temp.zip and creating a zip object
with ZipFile("world_happiness_competition_data.zip", 'r') as zObject:

    # Extracting all the members of the zip
    # into a specific location.
    zObject.extractall()

# %%
# Load data
import pandas as pd
X_train = pd.read_csv('world_happiness_competition_data/X_train.csv')
X_test = pd.read_csv('world_happiness_competition_data/X_test.csv')
y_train = pd.read_csv('world_happiness_competition_data/y_train.csv')
y_train_labels = y_train.idxmax(axis=1)

X_train.head()
# Out:
#   Country or region  GDP per capita  Social support  Healthy life expectancy  \
# 0              Peru           0.960           1.274                    0.854
# 1         Nicaragua           0.694           1.325                    0.835
# 2            Greece           1.181           1.156                    0.999
# 3             Qatar           1.684           1.313                    0.871
# 4        Uzbekistan           0.745           1.529                    0.756
#
#    Freedom to make life choices  Generosity  Perceptions of corruption  \
# 0                         0.455       0.083                      0.027
# 1                         0.435       0.200                      0.127
# 2                         0.067       0.000                      0.034
# 3                         0.555       0.220                      0.167
# 4                         0.631       0.322                      0.240
#
#          name    region                       sub-region  Terrorist_attacks
# 0        Peru  Americas  Latin America and the Caribbean          18.000000
# 1   Nicaragua  Americas  Latin America and the Caribbean         125.611111
# 2      Greece    Europe                  Southern Europe         112.000000
# 3       Qatar      Asia                     Western Asia          57.333333
# 4  Uzbekistan      Asia                     Central Asia         125.611111

# %% [markdown]
# ## Data Exploration and Visualization

# %% [markdown]
# ### Destriptive statistics

# %%
data = X_train.copy()
data['Happiness'] = y_train.idxmax(axis=1)
data.corr()
# Out:
# <ipython-input-3-79b11f026eeb>:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                               GDP per capita  Social support  \
# GDP per capita                      1.000000        0.753791
# Social support                      0.753791        1.000000
# Healthy life expectancy             0.840467        0.709605
# Freedom to make life choices        0.458313        0.502305
# Generosity                         -0.069164       -0.015965
# Perceptions of corruption           0.349372        0.279549
# Terrorist_attacks                  -0.352544       -0.339582
#
#                               Healthy life expectancy  \
# GDP per capita                               0.840467
# Social support                               0.709605
# Healthy life expectancy                      1.000000
# Freedom to make life choices                 0.419038
# Generosity                                  -0.024471
# Perceptions of corruption                    0.371450
# Terrorist_attacks                           -0.410411
#
#                               Freedom to make life choices  Generosity  \
# GDP per capita                                    0.458313   -0.069164
# Social support                                    0.502305   -0.015965
# Healthy life expectancy                           0.419038   -0.024471
# Freedom to make life choices                      1.000000    0.327923
# Generosity                                        0.327923    1.000000
# Perceptions of corruption                         0.496876    0.327683
# Terrorist_attacks                                -0.362758    0.032479
#
#                               Perceptions of corruption  Terrorist_attacks
# GDP per capita                                 0.349372          -0.352544
# Social support                                 0.279549          -0.339582
# Healthy life expectancy                        0.371450          -0.410411
# Freedom to make life choices                   0.496876          -0.362758
# Generosity                                     0.327683           0.032479
# Perceptions of corruption                      1.000000          -0.160908
# Terrorist_attacks                             -0.160908           1.000000

# %%
desc_stats = data.describe(include='all') # 'include=all' will provide statistics for both numeric and non-numeric columns

print(desc_stats)
# Out:
#        Country or region  GDP per capita  Social support  \
# count                 88       88.000000       88.000000
# unique                88             NaN             NaN
# top                 Peru             NaN             NaN
# freq                   1             NaN             NaN
# mean                 NaN        0.917148        1.213807
# std                  NaN        0.412638        0.293830
# min                  NaN        0.026000        0.000000
# 25%                  NaN        0.626000        1.113250
# 50%                  NaN        0.960000        1.249500
# 75%                  NaN        1.249000        1.463500
# max                  NaN        1.684000        1.624000
#
#         Healthy life expectancy  Freedom to make life choices  Generosity  \
# count                 88.000000                     88.000000   88.000000
# unique                      NaN                           NaN         NaN
# top                         NaN                           NaN         NaN
# freq                        NaN                           NaN         NaN
# mean                   0.745693                      0.379273    0.184705
# std                    0.237671                      0.156634    0.102516
# min                    0.105000                      0.000000    0.000000
# 25%                    0.567000                      0.267750    0.106750
# 50%                    0.806500                      0.408000    0.179500
# 75%                    0.898250                      0.493500    0.244500
# max                    1.141000                      0.631000    0.566000
#
#         Perceptions of corruption  name  region          sub-region  \
# count                   88.000000    88      88                  88
# unique                        NaN    88       5                  14
# top                           NaN  Peru  Europe  Sub-Saharan Africa
# freq                          NaN     1      26                  21
# mean                     0.115159   NaN     NaN                 NaN
# std                      0.103309   NaN     NaN                 NaN
# min                      0.000000   NaN     NaN                 NaN
# 25%                      0.049250   NaN     NaN                 NaN
# 50%                      0.083500   NaN     NaN                 NaN
# 75%                      0.145750   NaN     NaN                 NaN
# max                      0.453000   NaN     NaN                 NaN
#
#         Terrorist_attacks Happiness
# count           88.000000        88
# unique                NaN         5
# top                   NaN      High
# freq                  NaN        22
# mean           296.720179       NaN
# std            764.351472       NaN
# min              1.000000       NaN
# 25%              4.750000       NaN
# 50%             38.500000       NaN
# 75%            125.611111       NaN
# max           6023.000000       NaN

# %% [markdown]
# ## Explore bivariate results
#
# From the plots, given other variables unchanged, GDP per capital has positive relationship with the happiness for the countries; social support has positive relationship with the happiness for the countries; health life expectance has positive relationship with the happiness for the countries.
#
#
#
# Due to the low R squre(less than 0.5), Generosity, Freedom to make life choices,  Perceptions of corruption, and Terrorist_attacks, have a lower predictive power in predicting happiness levels.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score
import numpy as np

# Sample data (X_train has been previously defined)
data = X_train.copy()
data['Happiness'] = y_train.idxmax(axis=1)

# Mapping happiness categories to ordered numbers
happiness_mapping = {
    'Very Low': 1,
    'Low': 2,
    'Average': 3,
    'High': 4,
    'Very High': 5
}
data['Happiness'] = data['Happiness'].map(happiness_mapping)

# For each numeric column, visualize relationship with Happiness
for column in X_train.columns:
    if X_train[column].dtype in ['float64', 'int64']:  # If the column is numeric

        # Scatter plot
        plt.figure(figsize=(10, 6))
        sns.scatterplot(x=data[column], y=data['Happiness'], alpha=0.5)

        # Fit a linear regression model
        X_column = data[[column]].values
        y_happiness = data['Happiness'].values

        reg = LinearRegression().fit(X_column, y_happiness)
        y_pred = reg.predict(X_column)

        # Plot the regression line
        plt.plot(X_column, y_pred, color='red')

        # Calculate r-squared and coefficient
        r2 = r2_score(y_happiness, y_pred)
        coef = reg.coef_[0]

        # Display r-squared and coefficient on the plot
        plt.text(np.min(X_column), 4.5, f'$R^2 = {r2:.2f}$', fontsize=10)
        plt.text(np.min(X_column), 4.2, f'Coefficient = {coef:.2f}', fontsize=10)

        plt.title(f'Relationship between {column} and Happiness')
        plt.ylabel('Happiness Level')
        plt.xlabel(column)
        plt.show()

# %% [markdown]
# ###   Preprocess data using Sklearn Column Transformer/ Write and Save Preprocessor function

# %%
from sklearn.preprocessing import StandardScaler, OneHotEncoder
from sklearn.compose import ColumnTransformer, make_column_transformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.preprocessing import StandardScaler, OneHotEncoder

# We create the preprocessing pipelines for both numeric and categorical data.

numeric_features = X_train.drop(['Country or region', 'name', 'region', 'sub-region'], axis=1)
numeric_features=numeric_features.columns.tolist()

numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),
    ('scaler', StandardScaler())])

categorical_features = ['region', 'sub-region']

#Replacing missing values with Modal value and then one hot encoding.
categorical_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='most_frequent')),
    ('onehot', OneHotEncoder(handle_unknown='ignore'))])

# final preprocessor object set up with ColumnTransformer
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('cat', categorical_transformer, categorical_features)])

#Fit your preprocessor object
preprocess=preprocessor.fit(X_train)

# %%
# Write function to transform data with preprocessor

def preprocess_data(data):
    data.drop(['Country or region', 'name'], axis=1, inplace=True)
    preprocessed_data = preprocess.transform(data)
    return preprocessed_data

# %% [markdown]
# ##3. Fit model on preprocessed data and save preprocessor function and model

# %% [markdown]
# ### Examine features that predict happiness categories using one or more models that allow for automatic feature selection
# #### Explain any meaningful findings

# %% [markdown]
# ### Random Forest
# I used random forest to examine the features.
#
#  The plot shows the top features by feature importance. The results shows that GDP per capita, health metrics, and social support are the top three predictors of happiness.

# %%
from sklearn.ensemble import RandomForestClassifier
import matplotlib.pyplot as plt

#RandomForest model
rf = RandomForestClassifier(n_estimators=100)
rf.fit(preprocess_data(X_train.copy()), y_train)

# Get feature importances
feature_importances = rf.feature_importances_

# Combine feature names and importance scores
categorical_encoded_features = preprocess.named_transformers_['cat']['onehot'].get_feature_names_out(categorical_features)
all_features = numeric_features + list(categorical_encoded_features)
features = sorted(zip(feature_importances, all_features), reverse=True)

# Plot the top features
plt.barh([f[1] for f in features[:10]], [f[0] for f in features[:10]])
plt.xlabel('Importance')
plt.ylabel('Feature')
plt.title('Top 10 Important Features')
plt.gca().invert_yaxis()
plt.show()

# %% [markdown]
# #### Save preprocessor function to local "preprocessor.zip" file

# %%
import aimodelshare as ai

ai.export_preprocessor(preprocess_data,"")
# Out:
# Your preprocessor is now saved to 'preprocessor.zip'

# %% [markdown]
# ## 4. Generate predictions from X_test data and submit model to competition

# %%
#Set credentials using modelshare.org username/password

from aimodelshare.aws import set_credentials

#This is the unique rest api that powers this World Happiness Classification Playground -- make sure to update the apiurl for new competition deployments
apiurl="https://guku9jsrja.execute-api.us-east-2.amazonaws.com/prod/m"

set_credentials(apiurl=apiurl)
# Out:
# Modelshare.ai Username:··········
# Modelshare.ai Password:··········
# Modelshare.ai login credentials set successfully.

# %%
#Instantiate Competition
import aimodelshare as ai
mycompetition= ai.ModelPlayground(playground_url=apiurl)

# %% [markdown]
# ### Model 1: Random Forest
# #### n_estimators=100, max_depth=4

# %%
from sklearn.ensemble import RandomForestClassifier


model = RandomForestClassifier(n_estimators=100, max_depth=4)
model.fit(preprocess_data(X_train.copy()), y_train_labels)
model.score(preprocess_data(X_train.copy()), y_train_labels)
# Out:
# 0.9090909090909091

# %%
#Submit Model 1:

#-- Generate predicted values (Model 1)
prediction_labels = model.predict(preprocess_data(X_test.copy()))

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model = model,
                                 preprocessor="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# This ORT build has ['AzureExecutionProvider', 'CPUExecutionProvider'] enabled. Since ORT 1.9, you are required to explicitly set the providers parameter when instantiating InferenceSession. For example, onnxruntime.InferenceSession(..., providers=['AzureExecutionProvider', 'CPUExecutionProvider'], ...)
#
# Insert search tags to help users find your model (optional): Tian Model 1
# Provide any useful notes about your model (optional):
# Your model has been submitted to experiment as model version 7.
#
# Visit your Model Playground Page for more.
# https://www.modelshare.ai/detail/model:3862

# %%
# Get leaderboard to explore current best model architectures

# Get raw data in pandas data frame
data = mycompetition.get_leaderboard()

# Stylize leaderboard data
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_70782_row0_col0, #T_70782_row1_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 51.5%, transparent 51.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 50.3%, transparent 50.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 59.4%, transparent 59.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row0_col4, #T_70782_row0_col5, #T_70782_row0_col6, #T_70782_row0_col7, #T_70782_row1_col4, #T_70782_row1_col5, #T_70782_row1_col6, #T_70782_row1_col7, #T_70782_row2_col4, #T_70782_row2_col5, #T_70782_row2_col6, #T_70782_row2_col7, #T_70782_row3_col4, #T_70782_row3_col5, #T_70782_row3_col6, #T_70782_row3_col7, #T_70782_row4_col4, #T_70782_row4_col5, #T_70782_row4_col6, #T_70782_row4_col7, #T_70782_row5_col4, #T_70782_row5_col5, #T_70782_row5_col6, #T_70782_row5_col7, #T_70782_row6_col4, #T_70782_row6_col5, #T_70782_row6_col6, #T_70782_row6_col7 {
#   text-align: center;
# }
# #T_70782_row1_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 51.4%, transparent 51.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row1_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 59.0%, transparent 59.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row1_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 53.6%, transparent 53.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row2_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row2_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 48.9%, transparent 48.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row2_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 57.5%, transparent 57.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row2_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 52.7%, transparent 52.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row3_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 48.5%, transparent 48.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 46.6%, transparent 46.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 63.2%, transparent 63.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 51.7%, transparent 51.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row4_col0, #T_70782_row5_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 45.6%, transparent 45.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row4_col1, #T_70782_row5_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 45.7%, transparent 45.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row4_col2, #T_70782_row5_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 52.3%, transparent 52.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row4_col3, #T_70782_row5_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 47.5%, transparent 47.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row6_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 44.1%, transparent 44.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row6_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 41.0%, transparent 41.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row6_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 51.1%, transparent 51.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_70782_row6_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 47.2%, transparent 47.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_70782" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_70782_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_70782_level0_col1" class="col_heading level0 col1" >f1_score</th>
#       <th id="T_70782_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_70782_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_70782_level0_col4" class="col_heading level0 col4" >ml_framework</th>
#       <th id="T_70782_level0_col5" class="col_heading level0 col5" >model_type</th>
#       <th id="T_70782_level0_col6" class="col_heading level0 col6" >username</th>
#       <th id="T_70782_level0_col7" class="col_heading level0 col7" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_70782_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_70782_row0_col0" class="data row0 col0" >51.47%</td>
#       <td id="T_70782_row0_col1" class="data row0 col1" >50.31%</td>
#       <td id="T_70782_row0_col2" class="data row0 col2" >59.39%</td>
#       <td id="T_70782_row0_col3" class="data row0 col3" >53.69%</td>
#       <td id="T_70782_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_70782_row0_col5" class="data row0 col5" >RandomForestClassifier</td>
#       <td id="T_70782_row0_col6" class="data row0 col6" >newusertest</td>
#       <td id="T_70782_row0_col7" class="data row0 col7" >3</td>
#     </tr>
#     <tr>
#       <th id="T_70782_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_70782_row1_col0" class="data row1 col0" >51.47%</td>
#       <td id="T_70782_row1_col1" class="data row1 col1" >51.35%</td>
#       <td id="T_70782_row1_col2" class="data row1 col2" >58.96%</td>
#       <td id="T_70782_row1_col3" class="data row1 col3" >53.64%</td>
#       <td id="T_70782_row1_col4" class="data row1 col4" >sklearn</td>
#       <td id="T_70782_row1_col5" class="data row1 col5" >GradientBoostingClassifier</td>
#       <td id="T_70782_row1_col6" class="data row1 col6" >newusertest</td>
#       <td id="T_70782_row1_col7" class="data row1 col7" >4</td>
#     </tr>
#     <tr>
#       <th id="T_70782_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_70782_row2_col0" class="data row2 col0" >50.00%</td>
#       <td id="T_70782_row2_col1" class="data row2 col1" >48.88%</td>
#       <td id="T_70782_row2_col2" class="data row2 col2" >57.46%</td>
#       <td id="T_70782_row2_col3" class="data row2 col3" >52.72%</td>
#       <td id="T_70782_row2_col4" class="data row2 col4" >sklearn</td>
#       <td id="T_70782_row2_col5" class="data row2 col5" >RandomForestClassifier</td>
#       <td id="T_70782_row2_col6" class="data row2 col6" >newusertest</td>
#       <td id="T_70782_row2_col7" class="data row2 col7" >2</td>
#     </tr>
#     <tr>
#       <th id="T_70782_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_70782_row3_col0" class="data row3 col0" >48.53%</td>
#       <td id="T_70782_row3_col1" class="data row3 col1" >46.60%</td>
#       <td id="T_70782_row3_col2" class="data row3 col2" >63.17%</td>
#       <td id="T_70782_row3_col3" class="data row3 col3" >51.68%</td>
#       <td id="T_70782_row3_col4" class="data row3 col4" >sklearn</td>
#       <td id="T_70782_row3_col5" class="data row3 col5" >RandomForestClassifier</td>
#       <td id="T_70782_row3_col6" class="data row3 col6" >xutian0117</td>
#       <td id="T_70782

# %% [markdown]
# ## 5. Repeat submission process to improve place on leaderboard

# %% [markdown]
# ### Model2: Random Forest using GridSearchCV to fine tuning

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

# Define the hyperparameters and their possible values
param_grid = {
    'n_estimators': [100, 500],
    'max_depth': [None, 3,10 ],
    'min_samples_split': [None, 1,3,5],
    'min_samples_leaf': [None, 1,2,5],
    'max_features': ['auto',None]
}

# Initialize the classifier
rf = RandomForestClassifier()
grid_search = GridSearchCV(rf, param_grid, cv=5, n_jobs=-1, verbose=2)

# Fit to the data
grid_search.fit(preprocess_data(X_train.copy()), y_train_labels)

# Get the best parameters and best model
best_params = grid_search.best_params_
best_rf_model = grid_search.best_estimator_
best_score = grid_search.best_score_
print("Best parameters:", best_params)
print("Best score:", best_score)
# Out:
# Fitting 5 folds for each of 192 candidates, totalling 960 fits
# Best parameters: {'max_depth': 10, 'max_features': 'auto', 'min_samples_leaf': 2, 'min_samples_split': 5, 'n_estimators': 100}
# Best score: 0.7156862745098039
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py:378: FitFailedWarning:
# 600 fits failed out of a total of 960.
# The score on these train-test partitions for these parameters will be set to nan.
# If these failures are not expected, you can try to debug them by setting error_score='raise'.
#
# Below are more details about the failures:
# --------------------------------------------------------------------------------
# 240 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 340, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_leaf' parameter of RandomForestClassifier must be an int in the range [1, inf) or a float in the range (0.0, 1.0). Got None instead.
#
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 340, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got None instead.
#
# --------------------------------------------------------------------------------
# 180 fits failed with the following error:
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_validation.py", line 686, in _fit_and_score
#     estimator.fit(X_train, y_train, **fit_params)
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py", line 340, in fit
#     self._validate_params()
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/base.py", line 600, in _validate_params
#     validate_parameter_constraints(
#   File "/usr/local/lib/python3.10/dist-packages/sklearn/utils/_param_validation.py", line 97, in validate_parameter_constraints
#     raise InvalidParameterError(
# sklearn.utils._param_validation.InvalidParameterError: The 'min_samples_split' parameter of RandomForestClassifier must be an int in the range [2, inf) or a float in the range (0.0, 1.0]. Got 1 instead.
#
#   warnings.warn(some_fits_failed_message, FitFailedWarning)
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_search.py:952: UserWarning: One or more of the test scores are non-finite: [       nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.69346405 0.68235294 0.68235294 0.68300654        nan        nan
#         nan        nan 0.68235294 0.69411765 0.6379085  0.70522876
#         nan        nan        nan        nan 0.61372549 0.6372549
#  0.61503268 0.60326797        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.6248366  0.63594771 0.64771242 0.61372549
#         nan        nan        nan        nan 0.65882353 0.64771242
#  0.61437908 0.63594771        nan        nan        nan        nan
#  0.60196078 0.60196078 0.59084967 0.63594771        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.64836601 0.65947712
#  0.66993464 0.61372549        nan        nan        nan        nan
#  0.64771242 0.6372549  0.65947712 0.61437908        nan        nan
#         nan        nan 0.60196078 0.61437908 0.68235294 0.61372549
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#  0.60196078 0.6124183  0.63660131 0.6130719         nan        nan
#         nan        nan 0.64771242 0.62418301 0.6254902  0.62418301
#         nan        nan        nan        nan 0.62418301 0.6124183
#  0.59084967 0.6124183         nan        nan        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan 0.65816993 0.70457516 0.69542484 0.68169935
#         nan        nan        nan        nan 0.66013072 0.70522876
#  0.71568627 0.67124183        nan        nan        nan        nan
#  0.67124183 0.6254902  0.64705882 0.64836601        nan        nan
#         nan        nan        nan        nan        nan        nan
#         nan        nan        nan        nan 0.65947712 0.6248366
#  0.63660131 0.63594771        nan        nan        nan        nan
#  0.61437908 0.64705882 0.64771242 0.6248366         nan        nan
#         nan        nan 0.6254902  0.61372549 0.61372549 0.59084967]
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_forest.py:424: FutureWarning: `max_features='auto'` has been deprecated in 1.1 and will be removed in 1.3. To keep the past behaviour, explicitly set `max_features='sqrt'` or remove this parameter as it is also the default value for RandomForestClassifiers and ExtraTreesClassifiers.
#   warn(

# %%
#Submit Model 2:

#-- Generate predicted y values (Model 2)
prediction_labels = best_rf_model.predict(preprocess_data(X_test.copy()))

# Submit Model 2 to Competition Leaderboard
mycompetition.submit_model(model = best_rf_model,
                                 prediction_submission=prediction_labels,
                                 preprocessor="preprocessor.zip")
# Out:
# This ORT build has ['AzureExecutionProvider', 'CPUExecutionProvider'] enabled. Since ORT 1.9, you are required to explicitly set the providers parameter when instantiating InferenceSession. For example, onnxruntime.InferenceSession(..., providers=['AzureExecutionProvider', 'CPUExecutionProvider'], ...)
#
# Insert search tags to help users find your model (optional): Tian Model2
# Provide any useful notes about your model (optional):
# Your model has been submitted to experiment as model version 8.
#
# Visit your Model Playground Page for more.
# https://www.modelshare.ai/detail/model:3862

# %%
# Compare two or more models
data=mycompetition.compare_models([1,2], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_bd32d caption {
#   color: black;
#   font-size: 18px;
# }
# #T_bd32d_row4_col2, #T_bd32d_row4_col3, #T_bd32d_row12_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_bd32d">
#   <caption>Model type: RandomForestClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_bd32d_level0_col0" class="col_heading level0 col0" >param_name</th>
#       <th id="T_bd32d_level0_col1" class="col_heading level0 col1" >default_value</th>
#       <th id="T_bd32d_level0_col2" class="col_heading level0 col2" >model_version_1</th>
#       <th id="T_bd32d_level0_col3" class="col_heading level0 col3" >model_version_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_bd32d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_bd32d_row0_col0" class="data row0 col0" >bootstrap</td>
#       <td id="T_bd32d_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_bd32d_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_bd32d_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_bd32d_row1_col0" class="data row1 col0" >ccp_alpha</td>
#       <td id="T_bd32d_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_bd32d_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_bd32d_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_bd32d_row2_col0" class="data row2 col0" >class_weight</td>
#       <td id="T_bd32d_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_bd32d_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_bd32d_row2_col3" class="data row2 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_bd32d_row3_col0" class="data row3 col0" >criterion</td>
#       <td id="T_bd32d_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_bd32d_row3_col2" class="data row3 col2" >gini</td>
#       <td id="T_bd32d_row3_col3" class="data row3 col3" >gini</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_bd32d_row4_col0" class="data row4 col0" >max_depth</td>
#       <td id="T_bd32d_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_bd32d_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_bd32d_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_bd32d_row5_col0" class="data row5 col0" >max_features</td>
#       <td id="T_bd32d_row5_col1" class="data row5 col1" >sqrt</td>
#       <td id="T_bd32d_row5_col2" class="data row5 col2" >sqrt</td>
#       <td id="T_bd32d_row5_col3" class="data row5 col3" >sqrt</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_bd32d_row6_col0" class="data row6 col0" >max_leaf_nodes</td>
#       <td id="T_bd32d_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_bd32d_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_bd32d_row6_col3" class="data row6 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_bd32d_row7_col0" class="data row7 col0" >max_samples</td>
#       <td id="T_bd32d_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_bd32d_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_bd32d_row7_col3" class="data row7 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_bd32d_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_bd32d_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_bd32d_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_bd32d_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_bd32d_row9_col0" class="data row9 col0" >min_samples_leaf</td>
#       <td id="T_bd32d_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_bd32d_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_bd32d_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_bd32d_row10_col0" class="data row10 col0" >min_samples_split</td>
#       <td id="T_bd32d_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_bd32d_row10_col2" class="data row10 col2" >2</td>
#       <td id="T_bd32d_row10_col3" class="data row10 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_bd32d_row11_col0" class="data row11 col0" >min_weight_fraction_leaf</td>
#       <td id="T_bd32d_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_bd32d_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_bd32d_row11_col3" class="data row11 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_bd32d_row12_col0" class="data row12 col0" >n_estimators</td>
#       <td id="T_bd32d_row12_col1" class="data row12 col1" >100</td>
#       <td id="T_bd32d_row12_col2" class="data row12 col2" >300</td>
#       <td id="T_bd32d_row12_col3" class="data row12 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_bd32d_row13_col0" class="data row13 col0" >n_jobs</td>
#       <td id="T_bd32d_row13_col1" class="data row13 col1" >None</td>
#       <td id="T_bd32d_row13_col2" class="data row13 col2" >None</td>
#       <td id="T_bd32d_row13_col3" class="data row13 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_bd32d_row14_col0" class="data row14 col0" >oob_score</td>
#       <td id="T_bd32d_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_bd32d_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_bd32d_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_bd32d_row15_col0" class="data row15 col0" >random_state</td>
#       <td id="T_bd32d_row15_col1" class="data row15 col1" >None</td>
#       <td id="T_bd32d_row15_col2" class="data row15 col2" >None</td>
#       <td id="T_bd32d_row15_col3" class="data row15 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_bd32d_row16_col0" class="data row16 col0" >verbose</td>
#       <td id="T_bd32d_row16_col1" class="data row16 col1" >0</td>
#       <td id="T_bd32d_row16_col2" class="data row16 col2" >0</td>
#       <td id="T_bd32d_row16_col3" class="data row16 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_bd32d_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_bd32d_row17_col0" class="data row17 col0" >warm_start</td>
#       <td id="T_bd32d_row17_col1" class="data row17 col1" >False</td>
#       <td id="T_bd32d_row17_col2" class="data row17 col2" >False</td>
#       <td id="T_bd32d_row17_col3" class="data row17 col3" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Model 3: Decision Tree using GridSearchCV

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import GridSearchCV

param_grid = {
    'criterion': ['gini', 'entropy'],
    'max_depth': [None, 3, 5, 7, 10],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4, 6]
}
dt_model = DecisionTreeClassifier()

grid_search = GridSearchCV(dt_model, param_grid, cv=5, n_jobs=-1, verbose=2)

# Assuming you've encoded y_train_labels already
grid_search.fit(preprocess_data(X_train.copy()), y_train_labels)

best_params = grid_search.best_params_
best_dt_model = grid_search.best_estimator_
best_score = grid_search.best_score_

print("Best parameters:", best_params)
print("Best score:", best_score)
# Out:
# Fitting 5 folds for each of 120 candidates, totalling 600 fits
# Best parameters: {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2}
# Best score: 0.6248366013071895

# %%
#Submit Model 3:

#-- Generate predicted values
prediction_labels = best_dt_model.predict(preprocess_data(X_test.copy()))

# Submit to Competition Leaderboard
mycompetition.submit_model(model = best_dt_model,
                                 preprocessor="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# This ORT build has ['AzureExecutionProvider', 'CPUExecutionProvider'] enabled. Since ORT 1.9, you are required to explicitly set the providers parameter when instantiating InferenceSession. For example, onnxruntime.InferenceSession(..., providers=['AzureExecutionProvider', 'CPUExecutionProvider'], ...)
#
# Insert search tags to help users find your model (optional): Tian Model 3
# Provide any useful notes about your model (optional):
# Your model has been submitted to experiment as model version 10.
#
# Visit your Model Playground Page for more.
# https://www.modelshare.ai/detail/model:3862

# %%
# Get leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_22728_row0_col0, #T_22728_row3_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 48.2%, transparent 48.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 68.1%, transparent 68.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 53.8%, transparent 53.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row0_col4, #T_22728_row0_col5, #T_22728_row0_col6, #T_22728_row0_col7, #T_22728_row1_col4, #T_22728_row1_col5, #T_22728_row1_col6, #T_22728_row1_col7, #T_22728_row2_col4, #T_22728_row2_col5, #T_22728_row2_col6, #T_22728_row2_col7, #T_22728_row3_col4, #T_22728_row3_col5, #T_22728_row3_col6, #T_22728_row3_col7, #T_22728_row4_col4, #T_22728_row4_col5, #T_22728_row4_col6, #T_22728_row4_col7, #T_22728_row5_col4, #T_22728_row5_col5, #T_22728_row5_col6, #T_22728_row5_col7, #T_22728_row6_col4, #T_22728_row6_col5, #T_22728_row6_col6, #T_22728_row6_col7, #T_22728_row7_col4, #T_22728_row7_col5, #T_22728_row7_col6, #T_22728_row7_col7, #T_22728_row8_col4, #T_22728_row8_col5, #T_22728_row8_col6, #T_22728_row8_col7, #T_22728_row9_col4, #T_22728_row9_col5, #T_22728_row9_col6, #T_22728_row9_col7 {
#   text-align: center;
# }
# #T_22728_row1_col0, #T_22728_row2_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 51.5%, transparent 51.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row1_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 50.3%, transparent 50.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row1_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 59.4%, transparent 59.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row1_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row2_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 51.4%, transparent 51.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row2_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 59.0%, transparent 59.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row2_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 53.6%, transparent 53.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 48.9%, transparent 48.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 57.5%, transparent 57.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 52.7%, transparent 52.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row4_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 48.5%, transparent 48.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row4_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 46.6%, transparent 46.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row4_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 63.2%, transparent 63.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row4_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 51.7%, transparent 51.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row5_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 47.1%, transparent 47.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row5_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 43.9%, transparent 43.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row5_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 60.0%, transparent 60.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row5_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 50.8%, transparent 50.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row6_col0, #T_22728_row7_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 45.6%, transparent 45.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row6_col1, #T_22728_row7_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 45.7%, transparent 45.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row6_col2, #T_22728_row7_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 52.3%, transparent 52.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row6_col3, #T_22728_row7_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 47.5%, transparent 47.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row8_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 44.1%, transparent 44.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row8_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 41.0%, transparent 41.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row8_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 51.1%, transparent 51.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row8_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 47.2%, transparent 47.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_22728_row9_col0, #T_22728_row9_col1, #T_22728_row9_col2, #T_22728_row9_col3 {
#   text-align: center;
#   width: 10em;
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_22728" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_22728_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_22728_level0_col1" class="col_heading level0 col1" >f1_score</th>
#       <th id="T_22728_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_22728_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_22728_level0_col4" class="col_heading level0 col4" >ml_framework</th>
#       <th id="T_22728_level0_col5" class="col_heading level0 col5" >model_type</th>
#       <th id="T_22728_level0_col6" class="col_heading level0 col6" >username</th>
#       <th id="T_22728_level0_col7" class="col_heading level0 col7" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_22728_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_22728_row0_col0" class="data row0 col0" >50.00%</td>
#       <td id="T_22728_row0_col1" class="data row0 col1" >48.25%</td>
#       <td id="T_22728_row0_col2" class="data row0 col2" >68.07%</td>
#       <td id="T_22728_row0_col3" class="data row0 col3" >53.76%</td>
#       <td id="T_22728_row0_col4" class="data row0 col4" >sklearn</td>
#       <td id="T_22728_row0_col5" class="data row0 col5" >DecisionTreeClassifier</td>
#       <td id="T_22728_row0_col6" class="data row0 col6" >xutian0117</td>
#       <td id="T_22728_row0_col7" class="data row0 col7" >10</td>
#     </tr>
#     <tr>
#       <th id="T_22728_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_22728_row1_col0" class="data row1 col0" >51.47%</td>
#       <td id="T_22728_row1_col1" class="data row1 col1" >50.31%</td>
#       <td id="T_22728_row1_col2" class="data row1 col2" >59.39%</td>
#       <td id="T_22728_row1_col3" class="data row

# %%
# Compare two or more models
data=mycompetition.compare_models([1,2,4], verbose=1)
mycompetition.stylize_compare(data)
# Out:
# <style type="text/css">
# #T_da6d5 caption {
#   color: black;
#   font-size: 18px;
# }
# #T_da6d5_row4_col2, #T_da6d5_row4_col3, #T_da6d5_row12_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_da6d5">
#   <caption>Model type: RandomForestClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_da6d5_level0_col0" class="col_heading level0 col0" >param_name</th>
#       <th id="T_da6d5_level0_col1" class="col_heading level0 col1" >default_value</th>
#       <th id="T_da6d5_level0_col2" class="col_heading level0 col2" >model_version_1</th>
#       <th id="T_da6d5_level0_col3" class="col_heading level0 col3" >model_version_2</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_da6d5_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_da6d5_row0_col0" class="data row0 col0" >bootstrap</td>
#       <td id="T_da6d5_row0_col1" class="data row0 col1" >True</td>
#       <td id="T_da6d5_row0_col2" class="data row0 col2" >True</td>
#       <td id="T_da6d5_row0_col3" class="data row0 col3" >True</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_da6d5_row1_col0" class="data row1 col0" >ccp_alpha</td>
#       <td id="T_da6d5_row1_col1" class="data row1 col1" >0.000000</td>
#       <td id="T_da6d5_row1_col2" class="data row1 col2" >0.000000</td>
#       <td id="T_da6d5_row1_col3" class="data row1 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_da6d5_row2_col0" class="data row2 col0" >class_weight</td>
#       <td id="T_da6d5_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_da6d5_row2_col2" class="data row2 col2" >None</td>
#       <td id="T_da6d5_row2_col3" class="data row2 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_da6d5_row3_col0" class="data row3 col0" >criterion</td>
#       <td id="T_da6d5_row3_col1" class="data row3 col1" >gini</td>
#       <td id="T_da6d5_row3_col2" class="data row3 col2" >gini</td>
#       <td id="T_da6d5_row3_col3" class="data row3 col3" >gini</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_da6d5_row4_col0" class="data row4 col0" >max_depth</td>
#       <td id="T_da6d5_row4_col1" class="data row4 col1" >None</td>
#       <td id="T_da6d5_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_da6d5_row4_col3" class="data row4 col3" >5</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_da6d5_row5_col0" class="data row5 col0" >max_features</td>
#       <td id="T_da6d5_row5_col1" class="data row5 col1" >sqrt</td>
#       <td id="T_da6d5_row5_col2" class="data row5 col2" >sqrt</td>
#       <td id="T_da6d5_row5_col3" class="data row5 col3" >sqrt</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_da6d5_row6_col0" class="data row6 col0" >max_leaf_nodes</td>
#       <td id="T_da6d5_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_da6d5_row6_col2" class="data row6 col2" >None</td>
#       <td id="T_da6d5_row6_col3" class="data row6 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_da6d5_row7_col0" class="data row7 col0" >max_samples</td>
#       <td id="T_da6d5_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_da6d5_row7_col2" class="data row7 col2" >None</td>
#       <td id="T_da6d5_row7_col3" class="data row7 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_da6d5_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_da6d5_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_da6d5_row8_col2" class="data row8 col2" >0.000000</td>
#       <td id="T_da6d5_row8_col3" class="data row8 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_da6d5_row9_col0" class="data row9 col0" >min_samples_leaf</td>
#       <td id="T_da6d5_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_da6d5_row9_col2" class="data row9 col2" >1</td>
#       <td id="T_da6d5_row9_col3" class="data row9 col3" >1</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_da6d5_row10_col0" class="data row10 col0" >min_samples_split</td>
#       <td id="T_da6d5_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_da6d5_row10_col2" class="data row10 col2" >2</td>
#       <td id="T_da6d5_row10_col3" class="data row10 col3" >2</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_da6d5_row11_col0" class="data row11 col0" >min_weight_fraction_leaf</td>
#       <td id="T_da6d5_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_da6d5_row11_col2" class="data row11 col2" >0.000000</td>
#       <td id="T_da6d5_row11_col3" class="data row11 col3" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_da6d5_row12_col0" class="data row12 col0" >n_estimators</td>
#       <td id="T_da6d5_row12_col1" class="data row12 col1" >100</td>
#       <td id="T_da6d5_row12_col2" class="data row12 col2" >300</td>
#       <td id="T_da6d5_row12_col3" class="data row12 col3" >100</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_da6d5_row13_col0" class="data row13 col0" >n_jobs</td>
#       <td id="T_da6d5_row13_col1" class="data row13 col1" >None</td>
#       <td id="T_da6d5_row13_col2" class="data row13 col2" >None</td>
#       <td id="T_da6d5_row13_col3" class="data row13 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_da6d5_row14_col0" class="data row14 col0" >oob_score</td>
#       <td id="T_da6d5_row14_col1" class="data row14 col1" >False</td>
#       <td id="T_da6d5_row14_col2" class="data row14 col2" >False</td>
#       <td id="T_da6d5_row14_col3" class="data row14 col3" >False</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_da6d5_row15_col0" class="data row15 col0" >random_state</td>
#       <td id="T_da6d5_row15_col1" class="data row15 col1" >None</td>
#       <td id="T_da6d5_row15_col2" class="data row15 col2" >None</td>
#       <td id="T_da6d5_row15_col3" class="data row15 col3" >None</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_da6d5_row16_col0" class="data row16 col0" >verbose</td>
#       <td id="T_da6d5_row16_col1" class="data row16 col1" >0</td>
#       <td id="T_da6d5_row16_col2" class="data row16 col2" >0</td>
#       <td id="T_da6d5_row16_col3" class="data row16 col3" >0</td>
#     </tr>
#     <tr>
#       <th id="T_da6d5_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_da6d5_row17_col0" class="data row17 col0" >warm_start</td>
#       <td id="T_da6d5_row17_col1" class="data row17 col1" >False</td>
#       <td id="T_da6d5_row17_col2" class="data row17 col2" >False</td>
#       <td id="T_da6d5_row17_col3" class="data row17 col3" >False</td>
#     </tr>
#   </tbody>
# </table>
# <style type="text/css">
# #T_98308 caption {
#   color: black;
#   font-size: 18px;
# }
# #T_98308_row3_col2, #T_98308_row5_col2, #T_98308_row12_col2, #T_98308_row14_col2 {
#   background: tomato;
# }
# </style>
# <table id="T_98308">
#   <caption>Model type: GradientBoostingClassifier</caption>
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_98308_level0_col0" class="col_heading level0 col0" >param_name</th>
#       <th id="T_98308_level0_col1" class="col_heading level0 col1" >default_value</th>
#       <th id="T_98308_level0_col2" class="col_heading level0 col2" >model_version_4</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_98308_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_98308_row0_col0" class="data row0 col0" >ccp_alpha</td>
#       <td id="T_98308_row0_col1" class="data row0 col1" >0.000000</td>
#       <td id="T_98308_row0_col2" class="data row0 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_98308_row1_col0" class="data row1 col0" >criterion</td>
#       <td id="T_98308_row1_col1" class="data row1 col1" >friedman_mse</td>
#       <td id="T_98308_row1_col2" class="data row1 col2" >friedman_mse</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_98308_row2_col0" class="data row2 col0" >init</td>
#       <td id="T_98308_row2_col1" class="data row2 col1" >None</td>
#       <td id="T_98308_row2_col2" class="data row2 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_98308_row3_col0" class="data row3 col0" >learning_rate</td>
#       <td id="T_98308_row3_col1" class="data row3 col1" >0.100000</td>
#       <td id="T_98308_row3_col2" class="data row3 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_98308_row4_col0" class="data row4 col0" >loss</td>
#       <td id="T_98308_row4_col1" class="data row4 col1" >log_loss</td>
#       <td id="T_98308_row4_col2" class="data row4 col2" >log_loss</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_98308_row5_col0" class="data row5 col0" >max_depth</td>
#       <td id="T_98308_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_98308_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_98308_row6_col0" class="data row6 col0" >max_features</td>
#       <td id="T_98308_row6_col1" class="data row6 col1" >None</td>
#       <td id="T_98308_row6_col2" class="data row6 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_98308_row7_col0" class="data row7 col0" >max_leaf_nodes</td>
#       <td id="T_98308_row7_col1" class="data row7 col1" >None</td>
#       <td id="T_98308_row7_col2" class="data row7 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_98308_row8_col0" class="data row8 col0" >min_impurity_decrease</td>
#       <td id="T_98308_row8_col1" class="data row8 col1" >0.000000</td>
#       <td id="T_98308_row8_col2" class="data row8 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_98308_row9_col0" class="data row9 col0" >min_samples_leaf</td>
#       <td id="T_98308_row9_col1" class="data row9 col1" >1</td>
#       <td id="T_98308_row9_col2" class="data row9 col2" >1</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_98308_row10_col0" class="data row10 col0" >min_samples_split</td>
#       <td id="T_98308_row10_col1" class="data row10 col1" >2</td>
#       <td id="T_98308_row10_col2" class="data row10 col2" >2</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_98308_row11_col0" class="data row11 col0" >min_weight_fraction_leaf</td>
#       <td id="T_98308_row11_col1" class="data row11 col1" >0.000000</td>
#       <td id="T_98308_row11_col2" class="data row11 col2" >0.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_98308_row12_col0" class="data row12 col0" >n_estimators</td>
#       <td id="T_98308_row12_col1" class="data row12 col1" >100</td>
#       <td id="T_98308_row12_col2" class="data row12 col2" >50</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_98308_row13_col0" class="data row13 col0" >n_iter_no_change</td>
#       <td id="T_98308_row13_col1" class="data row13 col1" >None</td>
#       <td id="T_98308_row13_col2" class="data row13 col2" >None</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_98308_row14_col0" class="data row14 col0" >random_state</td>
#       <td id="T_98308_row14_col1" class="data row14 col1" >None</td>
#       <td id="T_98308_row14_col2" class="data row14 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_98308_row15_col0" class="data row15 col0" >subsample</td>
#       <td id="T_98308_row15_col1" class="data row15 col1" >1.000000</td>
#       <td id="T_98308_row15_col2" class="data row15 col2" >1.000000</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_98308_row16_col0" class="data row16 col0" >tol</td>
#       <td id="T_98308_row16_col1" class="data row16 col1" >0.000100</td>
#       <td id="T_98308_row16_col2" class="data row16 col2" >0.000100</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row17" class="row_heading level0 row17" >17</th>
#       <td id="T_98308_row17_col0" class="data row17 col0" >validation_fraction</td>
#       <td id="T_98308_row17_col1" class="data row17 col1" >0.100000</td>
#       <td id="T_98308_row17_col2" class="data row17 col2" >0.100000</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row18" class="row_heading level0 row18" >18</th>
#       <td id="T_98308_row18_col0" class="data row18 col0" >verbose</td>
#       <td id="T_98308_row18_col1" class="data row18 col1" >0</td>
#       <td id="T_98308_row18_col2" class="data row18 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_98308_level0_row19" class="row_heading level0 row19" >19</th>
#       <td id="T_98308_row19_col0" class="data row19 col0" >warm_start</td>
#       <td id="T_98308_row19_col1" class="data row19 col1" >False</td>
#       <td id="T_98308_row19_col2" class="data row19 col2" >False</td>
#     </tr>
#   </tbody>
# </table>

# %% [markdown]
# ### Model 4, GradientBoosting

# %%
# Here are several classic ML architectures you can consider choosing from to experiment with next:
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import GradientBoostingClassifier

#Example code to fit model:
model = GradientBoostingClassifier(n_estimators=50, learning_rate=1.0,
    max_depth=1, random_state=0).fit(preprocess_data(X_train.copy()), y_train_labels)
model.score(preprocess_data(X_train.copy()), y_train_labels)


#-- Generate predicted values
prediction_labels = model.predict(preprocess_data(X_test.copy()))

# Submit model to Competition Leaderboard
mycompetition.submit_model(model= model,
                                 preprocessor="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# This ORT build has ['AzureExecutionProvider', 'CPUExecutionProvider'] enabled. Since ORT 1.9, you are required to explicitly set the providers parameter when instantiating InferenceSession. For example, onnxruntime.InferenceSession(..., providers=['AzureExecutionProvider', 'CPUExecutionProvider'], ...)
#
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
# Your model has been submitted to experiment as model version 11.
#
# Visit your Model Playground Page for more.
# https://www.modelshare.ai/detail/model:3862

# %% [markdown]
# ### Model 5: Deep learning Model

# %%
import keras
from keras.models import Sequential
from keras.layers import Dense, Activation

feature_count=preprocess_data(X_train.copy()).shape[1] #count features in input data

keras_model = Sequential()
keras_model.add(Dense(128, input_dim=feature_count, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(64, activation='relu'))
keras_model.add(Dense(32, activation='relu'))

keras_model.add(Dense(5, activation='softmax'))

# Compile model
keras_model.compile(loss='categorical_crossentropy', optimizer='sgd', metrics=['accuracy'])

# Fitting the NN to the Training set
keras_model.fit(preprocess_data(X_train.copy()), y_train, ## Note that keras models require a one-hot-encoded y_train object
               batch_size = 20,
               epochs = 300, validation_split=0.25)
# Out:
# Epoch 1/300
# 4/4 [==============================] - 1s 100ms/step - loss: 1.6077 - accuracy: 0.2879 - val_loss: 1.5707 - val_accuracy: 0.3182
# Epoch 2/300
# 4/4 [==============================] - 0s 12ms/step - loss: 1.5953 - accuracy: 0.3030 - val_loss: 1.5664 - val_accuracy: 0.3182
# Epoch 3/300
# 4/4 [==============================] - 0s 13ms/step - loss: 1.5844 - accuracy: 0.3030 - val_loss: 1.5597 - val_accuracy: 0.3636
# Epoch 4/300
# 4/4 [==============================] - 0s 20ms/step - loss: 1.5751 - accuracy: 0.3182 - val_loss: 1.5548 - val_accuracy: 0.4091
# Epoch 5/300
# 4/4 [==============================] - 0s 18ms/step - loss: 1.5657 - accuracy: 0.3333 - val_loss: 1.5489 - val_accuracy: 0.4091
# Epoch 6/300
# 4/4 [==============================] - 0s 12ms/step - loss: 1.5557 - accuracy: 0.3333 - val_loss: 1.5432 - val_accuracy: 0.4091
# Epoch 7/300
# 4/4 [==============================] - 0s 15ms/step - loss: 1
300
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1892 - accuracy: 0.9545 - val_loss: 1.1282 - val_accuracy: 0.5909
# Epoch 283/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1917 - accuracy: 0.9697 - val_loss: 1.1114 - val_accuracy: 0.5909
# Epoch 284/300
# 4/4 [==============================] - 0s 12ms/step - loss: 0.1907 - accuracy: 0.9545 - val_loss: 1.0715 - val_accuracy: 0.6818
# Epoch 285/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1913 - accuracy: 0.9394 - val_loss: 1.1240 - val_accuracy: 0.5909
# Epoch 286/300
# 4/4 [==============================] - 0s 11ms/step - loss: 0.1880 - accuracy: 0.9545 - val_loss: 1.1531 - val_accuracy: 0.5909
# Epoch 287/300
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1875 - accuracy: 0.9697 - val_loss: 1.1406 - val_accuracy: 0.5909
# Epoch 288/300
# 4/4 [==============================] - 0s 10ms/step - loss: 0.1852 - accuracy: 0.9697 - val_loss: 1.1894 - val_accuracy: 0.5909
# Epoch 289/300
# 4/4 [==============================] - 0s 9ms/step - loss: 0.1883 - accuracy: 0.9697 - val_loss: 1.1736 - val_accuracy: 0.5909
# Epoch 290/300
# 4/4 [==============================] - 0s 16ms/step - loss: 0.1855 - accuracy: 0.9697 - val_loss: 1.1556 - val_accuracy: 0.5909
# Epoch 291/300
# 4/4 [==============================] - 0s 18ms/step - loss: 0.1817 - accuracy: 0.9697 - val_loss: 1.1574 - val_accuracy: 0.5909
# Epoch 292/300
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1787 - accuracy: 0.9697 - val_loss: 1.1550 - val_accuracy: 0.5909
# Epoch 293/300
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1784 - accuracy: 0.9697 - val_loss: 1.1651 - val_accuracy: 0.5909
# Epoch 294/300
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1786 - accuracy: 0.9697 - val_loss: 1.1522 - val_accuracy: 0.5909
# Epoch 295/300
# 4/4 [==============================] - 0s 19ms/step - loss: 0.1751 - accuracy: 0.9697 - val_loss: 1.1552 - val_accuracy: 0.5909
# Epoch 296/300
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1738 - accuracy: 0.9697 - val_loss: 1.1412 - val_accuracy: 0.5909
# Epoch 297/300
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1745 - accuracy: 0.9697 - val_loss: 1.1569 - val_accuracy: 0.5909
# Epoch 298/300
# 4/4 [==============================] - 0s 21ms/step - loss: 0.1773 - accuracy: 0.9697 - val_loss: 1.1882 - val_accuracy: 0.5909
# Epoch 299/300
# 4/4 [==============================] - 0s 22ms/step - loss: 0.1713 - accuracy: 0.9697 - val_loss: 1.1568 - val_accuracy: 0.5909
# Epoch 300/300
# 4/4 [==============================] - 0s 23ms/step - loss: 0.1722 - accuracy: 0.9697 - val_loss: 1.1569 - val_accuracy: 0.5909

# %%
# Submit keras model:

#-- Generate predicted y values
#Note: Keras predict returns the predicted column index location for classification models

prediction_column_index=keras_model.predict(preprocess_data(X_test.copy())).argmax(axis=1)

# extract correct prediction labels
prediction_labels = [y_train.columns[i] for i in prediction_column_index]

# Submit Model 1 to Competition Leaderboard
mycompetition.submit_model(model = keras_model,
                                 preprocessor="preprocessor.zip",
                                 prediction_submission=prediction_labels)
# Out:
# 3/3 [==============================] - 0s 3ms/step
# Timeout: Model to ONNX conversion is taking longer than expected. This can be the case for big models.
# Do you want to keep trying (1) or submit predictions only (2)? 2
#
# Insert search tags to help users find your model (optional):
# Provide any useful notes about your model (optional):
# Your model has been submitted to experiment as model version 12.
#
# Visit your Model Playground Page for more.
# https://www.modelshare.ai/detail/model:3862

# %%
# Check leaderboard

data = mycompetition.get_leaderboard()
mycompetition.stylize_leaderboard(data)
# Out:
# <style type="text/css">
# #T_efab2_row0_col0, #T_efab2_row4_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 50.0%, transparent 50.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row0_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 48.2%, transparent 48.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row0_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 68.1%, transparent 68.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row0_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 53.8%, transparent 53.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row0_col4, #T_efab2_row0_col5, #T_efab2_row0_col6, #T_efab2_row0_col7, #T_efab2_row1_col4, #T_efab2_row1_col5, #T_efab2_row1_col6, #T_efab2_row1_col7, #T_efab2_row2_col4, #T_efab2_row2_col5, #T_efab2_row2_col6, #T_efab2_row2_col7, #T_efab2_row3_col4, #T_efab2_row3_col5, #T_efab2_row3_col6, #T_efab2_row3_col7, #T_efab2_row4_col4, #T_efab2_row4_col5, #T_efab2_row4_col6, #T_efab2_row4_col7, #T_efab2_row5_col4, #T_efab2_row5_col5, #T_efab2_row5_col6, #T_efab2_row5_col7, #T_efab2_row6_col4, #T_efab2_row6_col5, #T_efab2_row6_col6, #T_efab2_row6_col7, #T_efab2_row7_col4, #T_efab2_row7_col5, #T_efab2_row7_col6, #T_efab2_row7_col7, #T_efab2_row8_col4, #T_efab2_row8_col5, #T_efab2_row8_col6, #T_efab2_row8_col7, #T_efab2_row9_col4, #T_efab2_row9_col5, #T_efab2_row9_col6, #T_efab2_row9_col7, #T_efab2_row10_col4, #T_efab2_row10_col5, #T_efab2_row10_col6, #T_efab2_row10_col7, #T_efab2_row11_col4, #T_efab2_row11_col5, #T_efab2_row11_col6, #T_efab2_row11_col7 {
#   text-align: center;
# }
# #T_efab2_row1_col0, #T_efab2_row2_col0, #T_efab2_row3_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 51.5%, transparent 51.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row1_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 50.3%, transparent 50.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row1_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 59.4%, transparent 59.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row1_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 53.7%, transparent 53.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row2_col1, #T_efab2_row3_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 51.4%, transparent 51.4%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row2_col2, #T_efab2_row3_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 59.0%, transparent 59.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row2_col3, #T_efab2_row3_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 53.6%, transparent 53.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row4_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 48.9%, transparent 48.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row4_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 57.5%, transparent 57.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row4_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 52.7%, transparent 52.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row5_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 48.5%, transparent 48.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row5_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 46.6%, transparent 46.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row5_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 63.2%, transparent 63.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row5_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 51.7%, transparent 51.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row6_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 47.1%, transparent 47.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row6_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 43.9%, transparent 43.9%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row6_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 60.0%, transparent 60.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row6_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 50.8%, transparent 50.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row7_col0, #T_efab2_row8_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 45.6%, transparent 45.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row7_col1, #T_efab2_row8_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 45.7%, transparent 45.7%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row7_col2, #T_efab2_row8_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 52.3%, transparent 52.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row7_col3, #T_efab2_row8_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 47.5%, transparent 47.5%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row9_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 44.1%, transparent 44.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row9_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 41.0%, transparent 41.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row9_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 51.1%, transparent 51.1%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row9_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 47.2%, transparent 47.2%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row10_col0 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #f5f8d6 42.6%, transparent 42.6%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row10_col1 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #c778c8 42.0%, transparent 42.0%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row10_col2 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #ff4971 46.3%, transparent 46.3%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row10_col3 {
#   text-align: center;
#   width: 10em;
#   background: linear-gradient(90deg, #aadbaa 44.8%, transparent 44.8%);
#   color: #251e1b;
#   font-size: 12px;
# }
# #T_efab2_row11_col0, #T_efab2_row11_col1, #T_efab2_row11_col2, #T_efab2_row11_col3 {
#   text-align: center;
#   width: 10em;
#   color: #251e1b;
#   font-size: 12px;
# }
# </style>
# <table id="T_efab2" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_efab2_level0_col0" class="col_heading level0 col0" >accuracy</th>
#       <th id="T_efab2_level0_col1" class="col_heading level0 col1" >f1_score</th>
#       <th id="T_efab2_level0_col2" class="col_heading level0 col2" >precision</th>
#       <th id="T_efab2_level0_col3" class="col_heading level0 col3" >recall</th>
#       <th id="T_efab2_level0_col4" class="col_heading level0 col4" >ml_framework</th>
#       <th id="T_efab2_level0_col5" class="col_heading level0 col5" >model_type</th>
#       <th id="T_efab2_level0_col6" class="col_heading level0 col6" >username</th>
#       <th id="T_efab2_level0_col7" class="col_heading level0 col7" >version</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_efab2_level0_row0" class="row_heading level0

# %% [markdown]
# ### To summary, Decision Tree Classifier model showing the best Precision(68.07%) and Recall(53.76%), Best parameters is : {'criterion': 'gini', 'max_depth': None, 'min_samples_leaf': 4, 'min_samples_split': 2}. Gradinet Boosting Classifier shows the best Accuracy(51.47%) and F1_Score(51.35%), n_estimators=50, learning_rate=1.0
